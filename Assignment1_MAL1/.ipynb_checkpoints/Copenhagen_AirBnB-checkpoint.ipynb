# %% [markdown]
# # 1. Getting Started: Airbnb Copenhagen

# %% [markdown]
# This assignment deals with the most recent Airbnb listings in Copenhagen. The data is collected from [Inside Airbnb](http://insideairbnb.com/copenhagen). Feel free to explore the website further in order to better understand the data. The data (*listings.csv*) has been collected as raw data and needs to be preprocessed.
#
# **Hand-in:** Hand in as a group in Itslearning in a **single**, well-organized and easy-to-read Jupyter Notebook. Please just use this notebook to complete the assignment.
#
# If your group consists of students from different classes, upload in **both** classes.
#
# The first cell does some preprocessing. Please just run these cells and do not change anything. The assignment starts below. Make sure that listings.csv' is in the same folder as this notebook

# %%
# pip install pandas
# pip install scikit-learn
import pandas as pd
import sklearn as sk

# load the data
data = pd.read_csv('listings.csv')

# filter relevant columns
data_limited = data[["id",
    "name",
    "host_id"  ,
    "host_name" , 
    "neighbourhood_cleansed"  ,
    "latitude"  ,
    "longitude"  ,
    "room_type"  ,
    "price"  ,
    "minimum_nights"  ,
    "number_of_reviews",  
    "last_review"  ,
    "review_scores_rating"  ,
    "review_scores_accuracy" , 
    "review_scores_cleanliness"  ,
    "review_scores_checkin"  ,
    "review_scores_communication"  ,
    "review_scores_location"  ,
    "review_scores_value"  ,
    "reviews_per_month"  ,
    "calculated_host_listings_count"  ,
    "availability_365",]]

# removing rows with no reviews

data_filtered = data_limited.loc[data_limited['number_of_reviews'] != 0]

# remove nan

data_filtered = data_filtered.dropna()
data_filtered.head()

# get a list of distinct values from neighbourhood_cleansed columns in data_filtered

neighbourhoods = data_filtered["neighbourhood_cleansed"].unique()

# replace e.g. Nrrbro with Nørrebro in neighbourhood_cleansed column

data_filtered["neighbourhood_cleansed"] = data_filtered["neighbourhood_cleansed"].replace("Nrrebro", "Nørrebro")
data_filtered["neighbourhood_cleansed"] = data_filtered["neighbourhood_cleansed"].replace("sterbro", "Østerbro")
data_filtered["neighbourhood_cleansed"] = data_filtered["neighbourhood_cleansed"].replace("Vanlse", "Vanløse")
data_filtered["neighbourhood_cleansed"] = data_filtered["neighbourhood_cleansed"].replace("Brnshj-Husum", "Brønshøj-Husum")
neighbourhoods = data_filtered["neighbourhood_cleansed"].unique()

# Remove dollar signs and commas and convert to float - note the prices are actually in DKK
data_filtered['price'] = data_filtered['price'].replace('[`\\$,]', '', regex=True).astype(float)

# Calculate the median price
median_price = data_filtered['price'].median()

# Create a new column 'price_category' with 0 for 'affordable' and 1 for 'expensive'
data_filtered['price_category'] = (data_filtered['price'] > median_price).astype(int)

display(data_filtered.head())

# Describe the apartments using a wordcloud
# Remember to install packages
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Combine the two lists of stop words
stop_words = ['Østerbro', 'Copenhagen', 'København', 'in', 'bedroom', 'bedrooms', 'bed', 'beds', 'bath', 'baths', 'Frederiksberg', 'V', 'Ø', 'SV', 'S', 'N', 'K', 'C', 'W', 'kbh', 'Ballerup', 'Hellerup', 'Valby', 'Vanløse', 'Brønhøj', 'Nørrebro', 'Vesterbro', "CPH", "with", "to", "of", "a", "the", "på", "i", "med", "af", "at", "city", "by", "apartment", "appartment", "lejlighed", "flat", "m2", "apt"]

# Convert the 'name' column to a single string
text = ' '.join(data_filtered['name'].astype(str))

# Create and generate a word cloud image
wordcloud = WordCloud(stopwords=stop_words, background_color="white", width=800, height=400).generate(text)

# Display the generated word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
#       id                                               name  host_id  \
# 0   6983                               Copenhagen 'N Livin'    16774
# 1  26057                Lovely house - most attractive area   109777
# 2  26473          City Centre Townhouse Sleeps 1-10 persons   112210
# 3  29118                    Best Location in Cool Istedgade   125230
# 4  31094  Beautiful, spacious, central, renovated Penthouse   129976
#
#   host_name     neighbourhood_cleansed   latitude  longitude        room_type  \
# 0     Simon                   Nørrebro  55.686410  12.547410  Entire home/apt
# 1      Kari                   Indre By  55.693070  12.576490  Entire home/apt
# 2     Julia                   Indre By  55.676020  12.575400  Entire home/apt
# 3      Nana  Vesterbro-Kongens Enghave  55.670230  12.555040  Entire home/apt
# 4      Ebbe  Vesterbro-Kongens Enghave  55.666602  12.555283  Entire home/apt
#
#     price  minimum_nights  ...  review_scores_accuracy  \
# 0   898.0               3  ...                    4.79
# 1  2600.0               4  ...                    4.93
# 2  3250.0               3  ...                    4.63
# 3   725.0               7  ...                    4.87
# 4  1954.0               3  ...                    4.82
#
#   review_scores_cleanliness  review_scores_checkin  \
# 0                      4.78                   4.86
# 1                      4.96                   4.93
# 2                      4.44                   4.78
# 3                      4.73                   5.00
# 4                      4.88                   4.87
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         4.89                    4.73                 4.71
# 1                         4.86                    4.94                 4.81
# 2                         4.70                    4.89                 4.59
# 3                         5.00                    4.87                 4.80
# 4                         4.82                    4.80                 4.53
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               1.08                               1                 0
# 1               0.55                               1               303
# 2               2.06                               3                56
# 3               0.16                               1                59
# 4               0.13                               1                 0
#
#    price_category
# 0               0
# 1               1
# 2               1
# 3               0
# 4               1
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Your tasks start here

# %% [markdown]
# ### 1. Since data science is so much fun, provide a word cloud of the names of the hosts, removing any names of non-persons. Does this more or less correspond with the distribution of names according to [Danmarks Statistik](https://www.dst.dk/da/Statistik/emner/borgere/navne/navne-i-hele-befolkningen)?

# %%
# State your solution here. Add more cells if needed.
host_names = data['host_name']
host_names.unique()
# Out:
# array(['Simon', 'Kari', 'Julia', ..., 'Sandy Phi', 'Martin Raae', 'Rakul'],
#       dtype=object)

# %%
host_names.value_counts()
# Out:
# host_name
# ApartmentinCopenhagen    179
# Christian                145
# Mette                    144
# Maria                    125
# Julie                    120
#                         ...
# Sacha Melanie              1
# Jónatan Logi               1
# Tabea                      1
# Céline                     1
# Rakul                      1
# Name: count, Length: 3792, dtype: int64

# %%
non_names = ["ApartmentinCopenhagen","And","og","Rent A"]
hostName = ' '.join(data_filtered['host_name'].astype(str))

# Create and generate a word cloud image
wordcloud = WordCloud(stopwords=non_names, background_color="white", width=800, height=400).generate(hostName)

# Display the generated word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ### 2. Using non-scaled versions of latitude and longitude, plot the listings data on a map.

# %%
# Plot the listings data on a map
smaller_data = data_filtered.sample(n = 10, random_state=1)
# The min zoom level is set to 12 to avoid showing the entire world map
import folium
map = folium.Map(location =[smaller_data['latitude'].mean(), smaller_data['longitude'].mean()], zoom_start=12, min_zoom=12)
icon=folium.Icon(icon='home')

# %%
for _, row in smaller_data.iterrows():
    folium.Marker(location=[row['latitude'], row['longitude']],
                  icon=folium.Icon(icon='home'),
                  ).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_88e2ebe2dae6a5022237881f374209c6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_88e2ebe2dae6a5022237881f374209c6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_88e2ebe2dae6a5022237881f374209c6 = L.map(
#                 &quot;map_88e2ebe2dae6a5022237881f374209c6&quot;,
#                 {
#                     center: [55.68470382, 12.5668566],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fe23ed664f9006175c224edae4909f74 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 12,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fe23ed664f9006175c224edae4909f74.addTo(map_88e2ebe2dae6a5022237881f374209c6);
#
#
#             var marker_9a4c533eb54c4529a44285b12e3836e4 = L.marker(
#                 [55.6576, 12.60158],
#                 {
# }
#             ).addTo(map_88e2ebe2dae6a5022237881f374209c6);
#
#
#             var icon_b8e2351ddd301326f3536537ea0bbc0b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_9a4c533eb54c4529a44285b12e3836e4.setIcon(icon_b8e2351ddd301326f3536537ea0bbc0b);
#
#
#             var marker_bfcc595e07d5469f27baa24431e6e4b0 = L.marker(
#                 [55.6629592, 12.60291],
#                 {
# }
#             ).addTo(map_88e2ebe2dae6a5022237881f374209c6);
#
#
#             var icon_94acd54719fb0fb01461e1e96db8bf7a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_bfcc595e07d5469f27baa24431e6e4b0.setIcon(icon_94acd54719fb0fb01461e1e96db8bf7a);
#
#
#             var marker_4d184e9ab6b8c0cf6d500595f1819de5 = L.marker(
#                 [55.67249899999999, 12.548796],
#                 {
# }
#             ).addTo(map_88e2ebe2dae6a5022237881f374209c6);
#
#
#             var icon_601f0b5db1202579682e02274fd93ab8 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_4d184e9ab6b8c0cf6d500595f1819de5.setIcon(icon_601f0b5db1202579682e02274fd93ab8);
#
#
#             var marker_c52ef7b028eaed96b5a934f92e7f906f = L.marker(
#                 [55.69806, 12.55467],
#                 {
# }
#             ).addTo(map_88e2ebe2dae6a5022237881f374209c6);
#
#
#             var icon_41cb1c111f4dbc6569154ec06a24405b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_c52ef7b028eaed96b5a934f92e7f906f.setIcon(icon_41cb1c111f4dbc6569154ec06a24405b);
#
#
#             var marker_f44a1d8169fc55ec30584e2f62923833 = L.marker(
#                 [55.69094, 12.56411],
#                 {
# }
#             ).addTo(map_88e2ebe2dae6a5022237881f374209c6);
#
#
#             var icon_0a6a8fe8ea7250e5cd737f30df1adf03 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_f44a1d8169fc55ec30584e2f62923833.setIcon(icon_0a6a8fe8ea7250e5cd737f30df1adf03);
#
#
#             var marker_5faec3deba0e69c4e955f65ca653234a = L.marker(
#                 [55.6863, 12.5662],
#                 {
# }
#             ).addTo(map_88e2ebe2dae6a5022237881f374209c6);
#
#
#             var icon_0c7833ef138da0ff30fbbf1226e4a5c8 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_5faec3deba0e69c4e955f65ca653234a.setIcon(icon_0c7833ef138da0ff30fbbf1226e4a5c8);
#
#
#             var marker_5dfcd9e304223775c5c6ae388a8b4d15 = L.marker(
#                 [55.68328, 12.55031],
#                 {
# }
#             ).addTo(map_88e2ebe2dae6a5022237881f374209c6);

# %% [markdown]
# ### 3. Create boxplots where you have the neighbourhood on the x-axis and price on the y-axis. What does this tell you about the listings in Copenhagen? Keep the x-axis as is and move different variables into the y-axis to see how things are distributed between the neighborhoods to create different plots (your choice).

# %%
# State your solution here. Add more cells if needed.
import matplotlib.pyplot as plt

neighborhoods = sorted(data_filtered['neighbourhood_cleansed'].unique())

# Create a boxplot
plt.figure(figsize=(16, 8))
plt.boxplot([data_filtered[data_filtered['neighbourhood_cleansed'] == neighbourhood_cleansed]['price'] for neighbourhood_cleansed in neighbourhoods], labels=neighbourhoods)
plt.xlabel('Neighborhood')
plt.ylabel('Price ($)')
plt.title('Boxplot of Neighborhoods by Price')
plt.xticks(rotation=90) 
plt.show()

# %% [markdown]
# ### 4. Do a descriptive analysis of the neighborhoods. Include information about room type in the analysis as well as one other self-chosen feature. The descriptive analysis should contain mean/average, mode, median, standard deviation/variance, minimum, maximum and quartiles.

# %%
import pandas as pd

# Select relevant columns
subset_data = data_filtered[['neighbourhood_cleansed', 'room_type', "price"]]

# Perform the aggregation with statistical metrics
agg_data = subset_data.groupby(['neighbourhood_cleansed', 'room_type']).agg(
    mean=('price', 'mean'),
    median=('price', 'median'),
    std=('price', 'std'),
    var=('price', 'var'),
    min=('price', 'min'),
    max=('price', 'max'),
    mode=('price', lambda x: x.mode().values[0] if not x.mode().empty else None),
    first_quartile=('price', lambda x: x.quantile(0.25)),
    third_quartile=('price', lambda x: x.quantile(0.75))
)

# Display the dataframe in Jupyter Notebook
display(agg_data)

# save the output to a CSV file
agg_data.to_csv("neighborhood_analysis.csv")

# print the output
print(agg_data)
# Out:
#                                                   mean  median          std  \
# neighbourhood_cleansed    room_type
# Amager Vest               Entire home/apt  1234.226623  1050.0   832.696891
#                           Private room     1032.966216   500.0  5299.018095
#                           Shared room      1051.500000  1051.5   112.429978
# Amager st                 Entire home/apt  1093.584071   900.0   721.982284
#                           Hotel room       1296.000000  1201.0   211.184753
#                           Private room      549.325581   471.0   293.995992
#                           Shared room      2575.000000  2575.0          NaN
# Bispebjerg                Entire home/apt   992.592520   800.0  1981.580545
#                           Private room      488.978947   400.0   353.674089
#                           Shared room       198.000000   198.0          NaN
# Brønshøj-Husum            Entire home/apt  1014.995370   900.0   555.669548
#                           Private room      445.552239   400.0   201.631624
#                           Shared room       211.500000   211.5    16.263456
# Frederiksberg             Entire home/apt  1292.472222  1037.0  1958.802772
#                           Private room      621.706767   500.0   567.611220
# Indre By                  Entire home/apt  1642.387192  1400.0  1072.616232
#                           Hotel room       1077.200000  1306.0   654.255098
#                           Private room      698.984375   582.0   380.070466
#                           Shared room       292.000000   280.0    67.577116
# Nørrebro                  Entire home/apt  1047.742192   950.0   583.703218
#                           Private room      650.121212   500.0   760.270040
#                           Shared room       324.666667   400.0   130.481161
# Valby                     Entire home/apt  1017.968889   899.0   635.434691
#                           Private room      498.157303   438.0   288.616366
# Vanløse                   Entire home/apt   954.425197   826.5   496.658320
#                           Private room      413.409091   337.5   194.578652
# Vesterbro-Kongens Enghave Entire home/apt  1181.435119  1000.0   698.122481
#                           Private room      574.366516   500.0   295.726896
#                           Shared room       330.500000   330.5   113.844192
# Østerbro                  Entire home/apt  1248.551107  1000.0  1438.908216
#                           Private room      605.461538   500.0   437.259030
#                           Shared room       469.000000   469.0          NaN
#
#                                                     var     min      max  \
# neighbourhood_cleansed    room_type
# Amager Vest               Entire home/apt  6.933841e+05   250.0  14000.0
#                           Private room     2.807959e+07   200.0  64900.0
#                           Shared room      1.264050e+04   972.0   1131.0
# Amager st                 Entire home/apt  5.212584e+05   240.0  10000.0
#                           Hotel room       4.459900e+04  1149.0   1538.0
#                           Private room     8.643364e+04   135.0   2000.0
#                           Shared room               NaN  2575.0   2575.0
# Bispebjerg                Entire home/apt  3.926661e+06   235.0  44000.0
#                           Private room     1.250854e+05   143.0   3000.0
#                           Shared room               NaN   198.0    198.0
# Brønshøj-Husum            Entire home/apt  3.087686e+05   250.0   4462.0
#                           Private room     4.065531e+04   145.0   1200.0
#                           Shared room      2.645000e+02   200.0    223.0
# Frederiksberg             Entire home/apt  3.836908e+06   300.0  58000.0
#                           Private room     3.221825e+05   185.0   5000.0
# Indre By                  Entire home/apt  1.150506e+06   350.0  20000.0
#                           Hotel room       4.280497e+05   204.0   1862.0
#                           Private room     1.444536e+05   165.0   2093.0
#                           Shared room      4.566667e+03   223.0    385.0
# Nørrebro                  Entire home/apt  3.407094e+05   216.0  12500.0
#                           Private room     5.780105e+05    79.0   8400.0
#                           Shared room      1.702533e+04   174.0    400.0
# Valby                     Entire home/apt  4.037772e+05   303.0   7429.0
#                           Private room     8.329941e+04   127.0   2000.0
# Vanløse                   Entire home/apt  2.466695e+05   269.0   3643.0
#                           Private room     3.786085e+04   200.0   1200.0
# Vesterbro-Kongens Enghave Entire home/apt  4.873750e+05   300.0  10800.0
#                           Private room     8.745440e+04   186.0   2000.0
#                           Shared room      1.296050e+04   250.0    411.0
# Østerbro                  Entire home/apt  2.070457e+06   268.0  41800.0
#                           Private room     1.911955e+05   200.0   3402.0
#                           Shared room               NaN   469.0    469.0
#
#                                              mode  first_quartile  \
# neighbourhood_cleansed    room_type
# Amager Vest               Entire home/apt  1000.0          814.00
#                           Private room      500.0          400.00
#                           Shared room       972.0         1011.75
# Amager st                 Entire home/apt  1000.0          700.00
#                           Hotel room       1149.0         1175.00
#                           Private room      450.0          400.00
#                           Shared room      2575.0         2575.00
# Bispebjerg                Entire home/apt   700.0          600.00
#                           Private room      300.0          300.00
#                           Shared room       198.0          198.00
# Brønshøj-Husum            Entire home/apt  1400.0          655.75
#                           Private room      500.0          320.00
#                           Shared room       200.0          205.75
# Frederiksberg             Entire home/apt  1000.0          822.50
#                           Private room      500.0          400.00
# Indre By                  Entire home/apt  1200.0         1021.25
#                           Hotel room       1306.0          393.50
#                           Private room      450.0          455.25
#                           Shared room       223.0          265.00
# Nørrebro                  Entire home/apt  1000.0          750.00
#                           Private room      500.0          400.00
#                           Shared room       400.0          287.00
# Valby                     Entire home/apt   700.0          699.00
#                           Private room      500.0          307.00
# Vanløse                   Entire home/apt   700.0          638.75
#                           Private room      300.0          271.50
# Vesterbro-Kongens Enghave Entire home/apt  1000.0          841.00
#                           Private room      500.0          414.00
#                           Shared room       250.0          290.25
# Østerbro                  Entire home/apt  1000.0          800.00
#                           Private room      400.0          400.00
#                           Shared room       469.0          469.00
#
#                                            third_quartile
# neighbourhood_cleansed    room_type
# Amager Vest               Entire home/apt         1480.00
#                           Private room             655.00
#                           Shared room             1091.25
# Amager st                 Entire home/apt         1200.00
#                           Hotel room              1369.50
#                           Private room             600.00
#                           Shared room             2575.00
# Bispebjerg                Entire home/apt         1000.00
#                           Private room             528.50
#                           Shared room              198.00
# Brønshøj-Husum            Entire home/apt         1250.00
#                           Private room             500.00
#                           Shared room              217.25
# Frederiksberg             Entire home/apt         1400.00
#                           Private room             700.00
# Indre By                  Entire home/apt         1911.00
#                           Hotel room              1553.75
#                           Private room             840.25
#                           Shared room              307.00
# Nørrebro                  Entire home/apt         1200.00
#                           Private room             700.00
#                           Shared room              400.00
# Valby                     Entire home/apt         1200.00
#                           Private room             550.00
# Vanløse                   Entire home/apt         1200.00
#                           Private room             500.25
# Vesterbro-Kongens Enghave Entire home/apt         1326.50
#                           Private room             643.00
#                           Shared room              370.75
# Østerbro                  Entire home/apt         1400.00
#                           Private room             679.75
#                           Shared room              469.00
#                                                   mean  median          std  \
# neighbourhood_cleansed    room_type
# Amager Vest               Entire home/apt  1234.226623  1050.0   832.696891
#                           Private room     1032.966216   500.0  5299.018095
#                           Shared room      1051.500000  1051.5   112.429978
# Amager st                 Entire home/apt  1093.584071   900.0   721.982284
#                           Hotel room       1296.000000  1201.0   211.184753
#                           Private room      549.325581   471.0   293.995992
#                           Shared room      2575.000000  2575.0          NaN
# Bispebjerg                Entire home/apt   992.592520   800.0  1981.580545
#                           Private room      488.978947   400.0   353.674089
#                           Shared room       198.000000   198.0          NaN
# Brønshøj-Husum            Entire home/apt  1014.995370   900.0   555.669548
#                           Private room      445.552239   400.0   201.631624
#                           Shared room       211.500000   211.5    16.263456
# Frederiksberg             Entire home/apt  1292.472222  1037.0  1958.802772
#                           Private room      621.706767   500.0   567.611220
# Indre By                  Entire home/apt  1642.387192  1400.0  1072.616232
#                           Hotel room       1077.200000  1306.0   654.255098
#                           Private room      698.984375   582.0   380.070466
#                           Shared room       292.000000   280.0    67.577116
# Nørrebro                  Entire home/apt  1047.742192   950.0   583.703218
#                           Private room      650.121212   500.0   760.270040
#                           Shared room       324.666667   400.0   130.481161
# Valby                     Entire home/apt  1017.968889   899.0   635.434691
#                           Private room      498.157303   438.0   288.616366
# Vanløse                   Entire home/apt   954.425197   826.5   496.658320
#                           Private room      413.409091   337.5   194.578652
# Vesterbro-Kongens Enghave Entire home/apt  1181.435119  1000.0   698.122481
#                           Private room      574.366516   500.0   295.726896
#                           Shared room       330.500000   330.5   113.844192
# Østerbro                  Entire home/apt  1248.551107  1000.0  1438.908216
#                           Private room      605.461538   500.0   437.259030
#                           Shared room       469.000000   469.0          NaN
#
#                                                     var     min      max  \
# neighbourhood_cleansed    room_type
# Amager Vest               Entire home/apt  6.933841e+05   250.0  14000.0
#                           Private room     2.807959e+07   200.0  64900.0
#                           Shared room      1.264050e+04   972.0   1131.0
# Amager st                 Entire home/apt  5.212584e+05   240.0  10000.0
#                           Hotel room       4.459900e+04  1149.0   1538.0
#                           Private room     8.643364e+04   135.0   2000.0
#                           Shared room               NaN  2575.0   2575.0
# Bispebjerg                Entire home/apt  3.926661e+06   235.0  44000.0
#                           Private room     1.250854e+05   143.0   3000.0
#                           Shared room               NaN   198.0    198.0
# Brønshøj-Husum            Entire home/apt  3.087686e+05   250.0   4462.0
#                           Private room     4.065531e+04   145.0   1200.0
#                           Shared room      2.645000e+02   200.0    223.0
# Frederiksberg             Entire home/apt  3.836908e+06   300.0  58000.0
#                           Private room     3.221825e+05   185.0   5000.0
# Indre By                  Entire home/apt  1.150506e+06   350.0  20000.0
#                           Hotel room       4.280497e+05   204.0   1862.0
#                           Private room     1.444536e+05   165.0   2093.0
#                           Shared room      4.566667e+03   223.0    385.0
# Nørrebro                  Entire home/apt  3.407094e+05   216.0  12500.0
#                           Private room     5.780105e+05    79.0   8400.0
#                           Shared room      1.702533e+04   174.0    400.0
# Valby                     Entire home/apt  4.037772e+05   303.0   7429.0
#                           Private room     8.329941e+04   127.0   2000.0
# Vanløse                   Entire home/apt  2.466695e+05   269.0   3643.0
#                           Private room     3.786085e+04   200.0   1200.0
# Vesterbro-Kongens Enghave Entire home/apt  4.873750e+05   300.0  10800.0
#                           Private room     8.745440e+04   186.0   2000.0
#                           Shared room      1.296050e+04   250.0    411.0
# Østerbro                  Entire home/apt  2.070457e+06   268.0  41800.0
#                           Private room     1.911955e+05   200.0   3402.0
#                           Shared room               NaN   469.0    469.0
#
#                                              mode  first_quartile  \
# neighbourhood_cleansed    room_type
# Amager Vest               Entire home/apt  1000.0          814.00
#                           Private room      500.0          400.00
#                           Shared room       972.0         1011.75
# Amager st                 Entire home/apt  1000.0          700.00
#                           Hotel room       1149.0         1175.00
#                           Private room      450.0          400.00
#                           Shared room      2575.0         2575.00
# Bispebjerg                Entire home/apt   700.0          600.00
#                           Private room      300.0          300.00
#                           Shared room       198.0          198.00
# Brønshøj-Husum            Entire home/apt  1400.0          655.75
#                           Private room      500.0          320.00
#                           Shared room       200.0          205.75
# Frederiksberg             Entire home/apt  1000.0          822.50
#                           Private room      500.0          400.00
# Indre By                  Entire home/apt  1200.0         1021.25
#                           Hotel room       1306.0          393.50
#                           Private room      450.0          455.25
#                           Shared room       223.0          265.00
# Nørrebro                  Entire home/apt  1000.0          750.00
#                           Private room      500.0          400.00
#                           Shared room       400.0          287.00
# Valby                     Entire home/apt   700.0          699.00
#                           Private room      500.0          307.00
# Vanløse                   Entire home/apt   700.0          638.75
#                           Private room      300.0          271.50
# Vesterbro-Kongens Enghave Entire home/apt  1000.0          841.00
#                           Private room      500.0          414.00
#                           Shared room       250.0          290.25
# Østerbro                  Entire home/apt  1000.0          800.00
#                           Private room      400.0          400.00
#                           Shared room       469.0          469.00
#
#                                            third_quartile
# neighbourhood_cleansed    room_type
# Amager Vest               Entire home/apt         1480.00
#                           Private room             655.00
#                           Shared room             1091.25
# Amager st                 Entire home/apt         1200.00
#                           Hotel room              1369.50
#                           Private room             600.00
#                           Shared room             2575.00
# Bispebjerg                Entire home/apt         1000.00
#                           Private room             528.50
#                           Shared room              198.00
# Brønshøj-Husum            Entire home/apt         1250.00
#                           Private room             500.00
#                           Shared room              217.25
# Frederiksberg             Entire home/apt         1400.00
#                           Private room             700.00
# Indre By                  Entire home/apt         1911.00
#                           Hotel room              1553.75
#                           Private room             840.25
#                           Shared room              307.00
# Nørrebro                  Entire home/apt         1200.00
#                           Private room             700.00
#                           Shared room              400.00
# Valby                     Entire home/apt         1200.00
#                           Private room             550.00
# Vanløse                   Entire home/apt         1200.00
#                           Private room             500.25
# Vesterbro-Kongens Enghave Entire home/apt         1326.50
#                           Private room             643.00
#                           Shared room              370.75
# Østerbro                  Entire home/apt         1400.00
#                           Private room             679.75
#                           Shared room              469.00

# %% [markdown]
# ### 5. Based on self-chosen features, and with "price_category" as your target, develop a k-Nearest Neighbor model to determine whether a rental property should be classified as 0 or 1. Remember to divide your data into training data and test data. Comment on your findings.

# %%
# State your solution here. Add more cells if needed.
